# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import ScriptProcessor
from sagemaker.processing import ProcessingInput
import boto3

# %%
role = get_execution_role()
session = sagemaker.Session()
default_bucket = session.default_bucket()

# Subir el script 3 actualizado a S3
s3 = boto3.client('s3')
s3.upload_file('TEST_PS_PE_3_reglas_negocio.py', default_bucket, 'scripts/PE/TEST_PS_PE_3_reglas_negocio.py')
print(f'Script subido a s3://{default_bucket}/scripts/PE/TEST_PS_PE_3_reglas_negocio.py')
# Out:
# Script subido a s3://sagemaker-us-east-2-399723489351/scripts/PE/TEST_PS_PE_3_reglas_negocio.py

# %%
# URIs de los outputs existentes de la corrida 1nhbm3v4v8up
base = 's3://sagemaker-us-east-2-399723489351/Pipeline-PedidoSugerido-Peru/1nhbm3v4v8up'
s3_limpieza = f'{base}/PS-Peru-Paso1-Limpieza/output/output_limpieza'
s3_modelado = f'{base}/PS-Peru-Paso2-Modelado/output/output_modelado'

print(f'Limpieza: {s3_limpieza}')
print(f'Modelado: {s3_modelado}')
# Out:
# Limpieza: s3://sagemaker-us-east-2-399723489351/Pipeline-PedidoSugerido-Peru/1nhbm3v4v8up/PS-Peru-Paso1-Limpieza/output/output_limpieza
# Modelado: s3://sagemaker-us-east-2-399723489351/Pipeline-PedidoSugerido-Peru/1nhbm3v4v8up/PS-Peru-Paso2-Modelado/output/output_modelado

# %%
processor = ScriptProcessor(
    command=['python3'],
    image_uri=sagemaker.image_uris.retrieve('sklearn', session.boto_region_name, '1.2-1'),
    role=role,
    instance_count=1,
    instance_type='ml.m5.2xlarge'
)

processor.run(
    code=f's3://{default_bucket}/scripts/PE/TEST_PS_PE_3_reglas_negocio.py',
    inputs=[
        ProcessingInput(source=s3_limpieza, destination='/opt/ml/processing/input/limpieza'),
        ProcessingInput(source=s3_modelado, destination='/opt/ml/processing/input/modelado'),
    ]
)
# Out:
# INFO:sagemaker.image_uris:Defaulting to only available Python version: py3
# INFO:sagemaker.image_uris:Defaulting to only supported image scope: cpu.
# INFO:sagemaker:Creating processing-job with name sagemaker-scikit-learn-2026-04-09-23-51-29-768
# ............Requirement already satisfied: pip in /miniconda3/lib/python3.9/site-packages (25.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /miniconda3/lib/python3.9/site-packages (80.9.0)
# Collecting setuptools
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.9/site-packages (0.43.0)
# Collecting wheel
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging>=24.0 in /miniconda3/lib/python3.9/site-packages (from wheel) (24.1)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 46.0 MB/s  0:00:00
# Downloading setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.0 MB/s  0:00:00
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.43.0
#     Uninstalling wheel-0.43.0:
#       Successfully uninstalled wheel-0.43.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-26.0.1 setuptools-82.0.1 wheel-0.46.3
# Collecting pyarrow==17.0.0
#   Downloading pyarrow-17.0.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.16.6 in ./miniconda3/lib/python3.9/site-packages (from pyarrow==17.0.0) (1.24.1)
# Downloading pyarrow-17.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 147.0 MB/s  0:00:00
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.1
#     Uninstalling pyarrow-14.0.1:
#       Successfully uninstalled pyarrow-14.0.1
# Successfully installed pyarrow-17.0.0
# Requirement already satisfied: numpy in ./miniconda3/lib/python3.9/site-packages (1.24.1)
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: pandas in ./miniconda3/lib/python3.9/site-packages (1.1.3)
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/lib/python3.9/site-packages (from pandas) (2025.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 179.6 MB/s  0:00:00
# Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 166.9 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, python-dateutil, numpy, pandas
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.3
#     Uninstalling pandas-1.1.3:
#       Successfully uninstalled pandas-1.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker-sklearn-container 2.0 requires numpy==1.24.1, but you have numpy 2.0.2 which is incompatible.
# sagemaker-sklearn-container 2.0 requires pandas==1.1.3, but you have pandas 2.3.3 which is incompatible.
# sagemaker-sklearn-container 2.0 requires python-dateutil==2.8.1, but you have python-dateutil 2.9.0.post0 which is incompatible.
# scipy 1.8.0 requires numpy<1.25.0,>=1.17.3, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2 pandas-2.3.3 python-dateutil-2.9.0.post0 tzdata-2026.1
# Collecting awswrangler[redshift]
#   Downloading awswrangler-3.14.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: boto3<2,>=1.20.32 in ./miniconda3/lib/python3.9/site-packages (from awswrangler[redshift]) (1.28.57)
# Requirement already satisfied: botocore<2,>=1.23.32 in ./miniconda3/lib/python3.9/site-packages (from awswrangler[redshift]) (1.31.85)
# Requirement already satisfied: numpy<3.0,>=1.26 in ./miniconda3/lib/python3.9/site-packages (from awswrangler[redshift]) (2.0.2)
# Requirement already satisfied: packaging<26.0,>=21.1 in ./miniconda3/lib/python3.9/site-packages (from awswrangler[redshift]) (24.1)
# Requirement already satisfied: pandas<3.0.0,>=1.2.0 in ./miniconda3/lib/python3.9/site-packages (from awswrangler[redshift]) (2.3.3)
# Requirement already satisfied: pyarrow<22.0.0,>=8.0.0 in ./miniconda3/lib/python3.9/site-packages (from awswrangler[redshift]) (17.0.0)
# Collecting typing-extensions<5,>=4.4.0 (from awswrangler[redshift])
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting redshift-connector<3,>=2.0.0 (from awswrangler[redshift])
#   Downloading redshift_connector-2.1.13-py3-none-any.whl.metadata (70 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./miniconda3/lib/python3.9/site-packages (from boto3<2,>=1.20.32->awswrangler[redshift]) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in ./miniconda3/lib/python3.9/site-packages (from boto3<2,>=1.20.32->awswrangler[redshift]) (0.7.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./miniconda3/lib/python3.9/site-packages (from botocore<2,>=1.23.32->awswrangler[redshift]) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in ./miniconda3/lib/python3.9/site-packages (from botocore<2,>=1.23.32->awswrangler[redshift]) (1.26.17)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/lib/python3.9/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler[redshift]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./miniconda3/lib/python3.9/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler[redshift]) (2026.1)
# Requirement already satisfied: six>=1.5 in ./miniconda3/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.23.32->awswrangler[redshift]) (1.15.0)
# Collecting scramp<1.5.0,>=1.2.0 (from redshift-connector<3,>=2.0.0->awswrangler[redshift])
#   Downloading scramp-1.4.6-py3-none-any.whl.metadata (19 kB)
# Collecting beautifulsoup4<5.0.0,>=4.13.5 (from redshift-connector<3,>=2.0.0->awswrangler[redshift])
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting boto3<2,>=1.20.32 (from awswrangler[redshift])
#   Downloading boto3-1.42.87-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector<3,>=2.0.0->awswrangler[redshift]) (2.32.3)
# Collecting lxml<=6.0.2,>=4.6.5 (from redshift-connector<3,>=2.0.0->awswrangler[redshift])
#   Downloading lxml-6.0.2-cp39-cp39-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in ./miniconda3/lib/python3.9/site-packages (from redshift-connector<3,>=2.0.0->awswrangler[redshift]) (82.0.1)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5.0.0,>=4.13.5->redshift-connector<3,>=2.0.0->awswrangler[redshift])
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting botocore<2,>=1.23.32 (from awswrangler[redshift])
#   Downloading botocore-1.42.87-py3-none-any.whl.metadata (5.9 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2,>=1.20.32->awswrangler[redshift])
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (2025.8.3)
# Collecting asn1crypto>=1.5.1 (from scramp<1.5.0,>=1.2.0->redshift-connector<3,>=2.0.0->awswrangler[redshift])
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Downloading awswrangler-3.14.0-py3-none-any.whl (380 kB)
# Downloading redshift_connector-2.1.13-py3-none-any.whl (156 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading boto3-1.42.87-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.87-py3-none-any.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 159.6 MB/s  0:00:00
# Downloading lxml-6.0.2-cp39-cp39-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 117.2 MB/s  0:00:00
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading scramp-1.4.6-py3-none-any.whl (12 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: asn1crypto, typing-extensions, soupsieve, scramp, lxml, botocore, beautifulsoup4, s3transfer, boto3, redshift-connector, awswrangler
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.31.85
#     Uninstalling botocore-1.31.85:
#       Successfully uninstalled botocore-1.31.85
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.7.0
#     Uninstalling s3transfer-0.7.0:
#       Successfully uninstalled s3transfer-0.7.0
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.28.57
#     Uninstalling boto3-1.28.57:
#       Successfully uninstalled boto3-1.28.57
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker-sklearn-container 2.0 requires boto3==1.28.57, but you have boto3 1.42.87 which is incompatible.
# sagemaker-sklearn-container 2.0 requires botocore<1.32.0,>=1.31.57, but you have botocore 1.42.87 which is incompatible.
# sagemaker-sklearn-container 2.0 requires numpy==1.24.1, but you have numpy 2.0.2 which is incompatible.
# sagemaker-sklearn-container 2.0 requires pandas==1.1.3, but you have pandas 2.3.3 which is incompatible.
# sagemaker-sklearn-container 2.0 requires python-dateutil==2.8.1, but you have python-dateutil 2.9.0.post0 which is incompatible.
# Successfully installed asn1crypto-1.5.1 awswrangler-3.14.0 beautifulsoup4-4.14.3 boto3-1.42.87 botocore-1.42.87 lxml-6.0.2 redshift-connector-2.1.13 s3transfer-0.16.0 scramp-1.4.6 soupsieve-2.8.3 typing-extensions-4.15.0
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: redshift-connector in ./miniconda3/lib/python3.9/site-packages (2.1.13)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scramp<1.5.0,>=1.2.0 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (1.4.6)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (2025.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.13.5 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (4.14.3)
# Requirement already satisfied: boto3<2.0.0,>=1.42.22 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (1.42.87)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (2.32.3)
# Requirement already satisfied: lxml<=6.0.2,>=4.6.5 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (6.0.2)
# Requirement already satisfied: botocore<2.0.0,>=1.12.201 in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (1.42.87)
# Requirement already satisfied: packaging in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (24.1)
# Requirement already satisfied: setuptools in ./miniconda3/lib/python3.9/site-packages (from redshift-connector) (82.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in ./miniconda3/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.13.5->redshift-connector) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./miniconda3/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.13.5->redshift-connector) (4.15.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./miniconda3/lib/python3.9/site-packages (from boto3<2.0.0,>=1.42.22->redshift-connector) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in ./miniconda3/lib/python3.9/site-packages (from boto3<2.0.0,>=1.42.22->redshift-connector) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./miniconda3/lib/python3.9/site-packages (from botocore<2.0.0,>=1.12.201->redshift-connector) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in ./miniconda3/lib/python3.9/site-packages (from botocore<2.0.0,>=1.12.201->redshift-connector) (1.26.17)
# Requirement already satisfied: six>=1.5 in ./miniconda3/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.12.201->redshift-connector) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector) (2025.8.3)
# Requirement already satisfied: asn1crypto>=1.5.1 in ./miniconda3/lib/python3.9/site-packages (from scramp<1.5.0,>=1.2.0->redshift-connector) (1.5.1)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading psycopg2_binary-2.9.11-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 81.3 MB/s  0:00:00
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: psycopg2-binary, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5 psycopg2-binary-2.9.11
# --- INICIANDO REGLAS DE NEGOCIO (Perú) ---
# Aplicando filtros de disponibilidad y stock...
#   Inicio: 44422 clientes, 5273466 filas
#   Después 5.-9 (ventas 14d): 44421 clientes, 2126923 filas
#   Después 5.-8 (S/M/B): 44421 clientes, 2126923 filas
#   Después 5.-7 (maestro): 44354 clientes, 742610 filas
#   Después filtro 608597: 44354 clientes, 742610 filas
#   Después 5.-5 (stock): 44325 clientes, 709319 filas
#   Después 5.-3 (sin precio): 44207 clientes, 670324 filas
# Aplicando filtros históricos...
#   Inicio: 44207 clientes, 669548 filas
#   Después 5.-2 (histórico): 44207 clientes, 669548 filas
#   Después 5.3 (compras 2 sem): 43742 clientes, 486473 filas
# Calculando métricas y armando dataset final...
#   Inicio: 43742 clientes, 486473 filas
# /opt/ml/processing/input/code/TEST_PS_PE_3_reglas_negocio.py:241: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   final_rec = final_rec.groupby("id_cliente").apply(
#   Después segmento: 43742 clientes, 93472 filas
# Exportando resultados a S3 para la fecha 2026-04-10...
# Total de clientes a recomendar: 42268
# SKUs usados: 151
# Archivos subidos exitosamente a S3.
# --- PROCESO FINALIZADO ---
